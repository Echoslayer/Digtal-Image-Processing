# %%
# Parameters
param1 = 0

# %%
# Parameters
param1 = 17

# %%
import os
print(os.getcwd())
os.chdir('../')
print(os.getcwd())
# Out:
# /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Notebooks/test_notebooks
# /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Notebooks

# %%
from mymodules import filters

# %%
from mymodules.basic_filters import get_lines_hough, equalized_image, image_binary

# %%
import inspect

# 獲取 filters 模組中的所有自定義函數（非內建）並將它們放入一個列表中
function_list = [obj for name, obj in inspect.getmembers(filters) if inspect.isfunction(obj) and obj.__module__ == filters.__name__]

# 你現在可以取用這些函數，例如調用它們
for func in function_list:
    print(f"Function name: {func.__name__}")
    # 如果需要調用函數，可以直接使用 func()
# Out:
# Function name: bilateralFilter
# Function name: differenceOfGaussian
# Function name: frangiFilter
# Function name: gaborFilter
# Function name: gaussianBlur
# Function name: hessianFilter
# Function name: highPassFilter
# Function name: horizontal_sobel
# Function name: kmeansFilter
# Function name: laplacian
# Function name: laplacianOfGaussian
# Function name: meanFilter
# Function name: medianBlur
# Function name: morphologicalGradient
# Function name: nonLocalMeansFilter
# Function name: ridgeFilter
# Function name: sideWindowFilter
# Function name: vertical_sobel

# %%
select_function = function_list[param1]
select_function.__name__
# Out:
# 'vertical_sobel'

# %%
import cv2  # 用於讀取圖片
import numpy as np  # 用於數學運算
import matplotlib.pyplot as plt  # 用於圖形顯示
import pathlib

# %%
import datetime
now = datetime.datetime.now()
f"{now.date()}"
# Out:
# '2024-10-03'

# %%
folder_path = pathlib.Path(r"/Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf")
folder_path = folder_path / f"{now.date()}"
folder_path.mkdir(parents=True, exist_ok=True) # 確保目錄存在，不存在則創建
folder_path.as_posix()
# Out:
# '/Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03'

# %%
template_folder_path = folder_path / 'template'
template_folder_path.mkdir(parents=True, exist_ok=True)

# %%
import os
origin_image_folder = pathlib.Path(r"/Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/Data/Exp_20240925_AUO")
origin_images = os.listdir(origin_image_folder.as_posix())
origin_images = [image for image in sorted(origin_images) if image[-4:]==".tif"]
origin_images
# Out:
# ['1_1.tif',
#  '1_2.tif',
#  '2_1.tif',
#  '2_2.tif',
#  '3_1.tif',
#  '3_2.tif',
#  '4_1.tif',
#  '4_2.tif',
#  '5_1.tif',
#  '5_2.tif',
#  '6_1.tif',
#  '6_2.tif']

# %%
origin_image_path = origin_image_folder / origin_images[0]
origin_name = origin_image_path.name
origin_name
# Out:
# '1_1.tif'

# %%
export_pdf = True
notebook_image_print = False
# fonts = [r"F:\Code\Digital-Image-Processing\Code\Resources\Fonts\Times New Roman.ttf", r"F:\Code\Digital-Image-Processing\Code\Resources\Fonts\kaiu.ttf"]
fonts = [r"/Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/Fonts/Times New Roman.ttf", r"/Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/Fonts/kaiu.ttf"]
pdf_content = [
    {'type':'title', 'add': 'AOI Report', 'font':0}
    ]

# %%
import datetime
now = datetime.datetime.now()
pdfname = folder_path / f"{now.date()}_{select_function.__name__}_aoireport.pdf"
pdfname = pdfname.as_posix()
pdfname
# Out:
# '/Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/2024-10-03_vertical_sobel_aoireport.pdf'

# %%
origin_image_path = origin_image_folder / origin_images[0]
origin_name = origin_image_path.name
origin_name
# Out:
# '1_1.tif'

# %%
from mymodules.image_manager import ImageManager
origin_im = ImageManager(origin_image_path.as_posix())

# %%
suffix = origin_im.path.suffix
suffix
# Out:
# '.tif'

# %%
# for i in range(len(origin_images)-1):    
#     # 讀取圖片
#     origin_image_path = origin_image_folder / origin_images[i]
#     origin_name = origin_image_path.name
#     origin_name

#     origin_im = ImageManager(origin_image_path.as_posix())
#     origin_im.choose_rgb('b')

#     origin_im.crop(1100, 1350, 200, 750)
#     origin_im.save(output_folder=template_folder_path)
#     image_name = origin_im.path.stem
#     image_path = (template_folder_path / (image_name + suffix)).as_posix()

#     addcontent = [
#         {'type':'content', 'add': "原圖: "+image_name, 'font':1},
#         {'type':'image', 'add': image_path, 'font':0},]
#     pdf_content.extend(addcontent)
    
#     # equalized_image
#     process_im = origin_im.process(equalized_image)
#     image_name = image_name+"_"+process_im.path.stem
#     process_im.save(name=image_name,output_folder=template_folder_path)

#     image_path = (template_folder_path / (image_name + suffix)).as_posix()

#     addcontent = [
#         {'type':'content', 'add': image_name, 'font':1},
#         {'type':'image', 'add': image_path, 'font':0},]
#     pdf_content.extend(addcontent)

# %%
pdf_content2 = []
for i in range(len(origin_images)-1):    
    # 讀取圖片
    origin_image_path = origin_image_folder / origin_images[i]
    origin_name = origin_image_path.name
    origin_name

    origin_im = ImageManager(origin_image_path.as_posix())
    origin_im.choose_rgb('b')

    origin_im.crop(1100, 1350, 200, 750)
    origin_im.save(output_folder=template_folder_path)
    
    # 應用濾波器
    process_im = origin_im.process(select_function)
    process_im.save(output_folder=template_folder_path)

    image_name = process_im.path.stem + origin_im.path.stem + "_"
    image_path = (template_folder_path / (image_name + suffix)).as_posix()

    # addcontent = [
    #     {'type':'content', 'add': image_name, 'font':1},
    #     {'type':'image', 'add': image_path, 'font':0},]
    # pdf_content.extend(addcontent)

    # 接下來進行二值化處理
    b_process_im = process_im.process(image_binary)
    image_name = "binary_"+image_name
    b_process_im.save(name=image_name,output_folder=template_folder_path)
    
    image_path = (template_folder_path / (image_name + suffix)).as_posix()
    addcontent = [
        {'type':'content', 'add': image_name, 'font':1},
        {'type':'image', 'add': image_path, 'font':0},]
    pdf_content.extend(addcontent)

    # 接著進行霍夫線檢測
    lines_im = b_process_im.process(get_lines_hough, params={'threshold': 30, 'min_line_length': 50, 'max_line_gap': 25})
    
    image_name = "lines_"+image_name
    
    lines_im.save(name=image_name, output_folder=template_folder_path)

    image_path = (template_folder_path / (image_name + suffix)).as_posix()
    addcontent = [
        {'type':'content', 'add': image_name, 'font':1},
        {'type':'image', 'add': image_path, 'font':0},]
    pdf_content2.extend(addcontent)

pdf_content.extend(pdf_content2)
# Out:
# Image changed to Blue channel
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/1_1.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/binary_vertical_sobel1_1_.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/lines_binary_vertical_sobel1_1_.tif
# Image changed to Blue channel
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/1_2.tif
# File with the same name exists. Saving with timestamp: /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/binary_vertical_sobel1_2_.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/lines_binary_vertical_sobel1_2_.tif
# Image changed to Blue channel
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/2_1.tif
# File with the same name exists. Saving with timestamp: /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/binary_vertical_sobel2_1_.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/lines_binary_vertical_sobel2_1_.tif
# Image changed to Blue channel
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/2_2.tif
# File with the same name exists. Saving with timestamp: /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/binary_vertical_sobel2_2_.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/lines_binary_vertical_sobel2_2_.tif
# Image changed to Blue channel
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/3_1.tif
# File with the same name exists. Saving with timestamp: /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/binary_vertical_sobel3_1_.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/lines_binary_vertical_sobel3_1_.tif
# Image changed to Blue channel
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/3_2.tif
# File with the same name exists. Saving with timestamp: /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/binary_vertical_sobel3_2_.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/lines_binary_vertical_sobel3_2_.tif
# Image changed to Blue channel
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/4_1.tif
# File with the same name exists. Saving with timestamp: /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/binary_vertical_sobel4_1_.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/lines_binary_vertical_sobel4_1_.tif
# Image changed to Blue channel
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/4_2.tif
# File with the same name exists. Saving with timestamp: /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/binary_vertical_sobel4_2_.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/lines_binary_vertical_sobel4_2_.tif
# Image changed to Blue channel
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/5_1.tif
# File with the same name exists. Saving with timestamp: /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/binary_vertical_sobel5_1_.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/lines_binary_vertical_sobel5_1_.tif
# Image changed to Blue channel
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/5_2.tif
# File with the same name exists. Saving with timestamp: /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/binary_vertical_sobel5_2_.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/lines_binary_vertical_sobel5_2_.tif
# Image changed to Blue channel
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/6_1.tif
# File with the same name exists. Saving with timestamp: /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/vertical_sobel_20241003_213941.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/binary_vertical_sobel6_1_.tif
# Image saved to /Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template/lines_binary_vertical_sobel6_1_.tif

# %%
from mymodules.pdf_report import PDFReport
report = PDFReport(name=pdfname, fonts=fonts)

for content in pdf_content:
    if content.get('type') == 'title':
        report.add_title(content.get('add'), font=content.get('font'))
    elif content.get('type') == 'content':
        report.add_content(content.get('add'), font=content.get('font'))
    elif content.get('type') == 'image':
        report.add_image(content.get('add'))
    
report.create()
# Out:
# PDF報告已生成：/Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/2024-10-03_vertical_sobel_aoireport.pdf

# %%
# !rm -r '/Users/xieweizhe/Desktop/MacCode/Digital-Image-Processing/Code/Resources/outputs/pdf/2024-10-03/template'
